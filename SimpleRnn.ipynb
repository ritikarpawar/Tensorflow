# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikarpawar/Tensorflow/blob/main/SimpleRnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

x = np.linspace(0, 50, 100)
y = np.sin(x)

X = []
target = []

seq_len = 10
for i in range(len(y) - seq_len):
    X.append(y[i:i+seq_len])
    target.append(y[i+seq_len])

X = np.array(X)
target = np.array(target)
X = X.reshape((X.shape[0], X.shape[1], 1))


model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(
        10,
        activation='relu',
        input_shape=(seq_len,1)
    ),
    tf.keras.layers.Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse'
)

model.fit(X, target, epochs=50, verbose=0)

pred = model.predict(X)

print("Actual:", target[:5])

print("Predicted:", pred[:5].flatten())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Actual: [-0.94338126 -0.66510151 -0.22074597  0.27872982  0.7086068 ]
# Predicted: [-0.6209399  -0.6523896  -0.47314343 -0.13949421  0.1287849 ]
