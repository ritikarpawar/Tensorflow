# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikarpawar/Tensorflow/blob/main/Optimisers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# Load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0


# Function to create CNN model
def create_model():

    model = tf.keras.Sequential([

        tf.keras.Input(shape=(32,32,3)),

        tf.keras.layers.Conv2D(32, 3, activation='relu'),

        tf.keras.layers.MaxPooling2D(),

        tf.keras.layers.Flatten(),

        tf.keras.layers.Dense(64, activation='relu'),

        tf.keras.layers.Dense(10, activation='softmax')
    ])

    return model


# Optimizers to compare
optimizers = {
    "Adam": tf.keras.optimizers.Adam(),
    "RMSprop": tf.keras.optimizers.RMSprop(),
    "SGD": tf.keras.optimizers.SGD()
}


# Train and evaluate
for name, opt in optimizers.items():

    print(f"\nOptimizer: {name}")

    model = create_model()

    model.compile(
        optimizer=opt,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X_train,
        y_train,
        epochs=3,
        validation_split=0.1,
        verbose=1
    )

    loss, acc = model.evaluate(X_test, y_test)

    print("Test Accuracy:", acc)
# Out:
# Optimizer: Adam
# Epoch 1/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 26ms/step - accuracy: 0.4516 - loss: 1.5457 - val_accuracy: 0.5458 - val_loss: 1.2885
# Epoch 2/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.5714 - loss: 1.2253 - val_accuracy: 0.5944 - val_loss: 1.1625
# Epoch 3/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.6136 - loss: 1.1115 - val_accuracy: 0.6310 - val_loss: 1.0823
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6185 - loss: 1.1053
# Test Accuracy: 0.6184999942779541
#
# Optimizer: RMSprop
# Epoch 1/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 25ms/step - accuracy: 0.4449 - loss: 1.5565 - val_accuracy: 0.5172 - val_loss: 1.3431
# Epoch 2/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.5598 - loss: 1.2531 - val_accuracy: 0.5280 - val_loss: 1.3366
# Epoch 3/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.6024 - loss: 1.1372 - val_accuracy: 0.5766 - val_loss: 1.2297
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5681 - loss: 1.2443
# Test Accuracy: 0.5680999755859375
#
# Optimizer: SGD
# Epoch 1/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3151 - loss: 1.9193 - val_accuracy: 0.3934 - val_loss: 1.7258
# Epoch 2/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.4423 - loss: 1.5770 - val_accuracy: 0.3974 - val_loss: 1.6819
# Epoch 3/3
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.5053 - loss: 1.3942 - val_accuracy: 0.5034 - val_loss: 1.3974
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.4975 - loss: 1.3923
# Test Accuracy: 0.4975000023841858
